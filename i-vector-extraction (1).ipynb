# %%
import os
import librosa
import numpy as np
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA
import joblib
import csv

# %%
# Function to extract features from a single audio file
def extract_features(audio_signal, sr=22050, n_mfcc=13):
    #print("Extracting features...")
    mfccs = librosa.feature.mfcc(y=audio_signal, sr=sr, n_mfcc=n_mfcc)
    #print(f"Extracted MFCCs shape: {mfccs.shape}")
    return mfccs.T

# Process all audio files in a directory to extract features
def process_audio_files(directory):
    all_features = []
    print(f"Extracting mfcc of all audio in {directory}")
    for filename in os.listdir(directory):
        if filename.endswith('.wav'):
            file_path = os.path.join(directory, filename)
            #print(f"Processing file: {file_path}")
            audio_signal, sr = librosa.load(file_path, sr=22050)
            #print(f"Loaded audio file with sample rate: {sr}")
            features = extract_features(audio_signal, sr)
            all_features.append(features)
    all_features = np.vstack(all_features)
    print(f"Extracted mfcc of all audio {directory}")
    print(f"Combined features shape: {all_features.shape}")
    return all_features

# Train a Universal Background Model (UBM)
def train_ubm(features, n_components=512):
    print("Training UBM...")
    gmm = GaussianMixture(n_components=n_components, covariance_type='diag')
    gmm.fit(features)
    print("UBM trained.")
    return gmm

# Train a total variability matrix (T-matrix)

def train_t_matrix(features, supervector_size, n_factors=400):
    print(f"Training T-matrix with {supervector_size} dimensions and {n_factors} factors...")
    pca = PCA(n_components=n_factors)
    pca.fit(features)
    t_matrix = np.random.rand(supervector_size, n_factors)  # Adjust to match supervector size
    print(f"T-matrix shape: {t_matrix.shape}")
    print("T-matrix trained.")
    return t_matrix


# Function to extract i-vectors using UBM and T-matrix
def extract_i_vectors(features, ubm, t_matrix):
    print("Extracting i-vector...")
    # Calculate posterior probabilities for each Gaussian component
    posteriors = ubm.predict_proba(features)
    
    # Calculate supervector by taking the weighted mean of the features
    supervector = np.dot(posteriors.T, features)
    
    # Flatten the supervector
    supervector = supervector.flatten()
    
    # Ensure that the T-matrix dimensions match the supervector size
    if t_matrix.shape[0] != supervector.size:
        raise ValueError(f"T-matrix and supervector size mismatch: T-matrix has {t_matrix.shape[0]} rows, supervector has {supervector.size} elements.")
    
    # Project the supervector onto the lower-dimensional i-vector space using the T-matrix
    i_vector = np.dot(supervector, t_matrix)
    
    # Normalize the i-vector (optional but common in i-vector extraction)
    i_vector /= np.linalg.norm(i_vector)
    
    print(f"i-vector shape: {i_vector.shape}")
    return i_vector

# %%
# Directory containing the large universal dataset for training
universal_dataset_directory = '/kaggle/input/mic-dev-eval/mic'

# Process the universal dataset and extract features
print("Processing universal dataset...")
universal_features = process_audio_files(universal_dataset_directory)
# Out:
# Processing universal dataset...
# Extracting mfcc of all audio in /kaggle/input/mic-dev-eval/mic
# Extracted mfcc of all audio /kaggle/input/mic-dev-eval/mic
# Combined features shape: (584029, 13)

# %%
ubm_model_path = 'ubm_model.joblib'
t_matrix_path = 't_matrix.joblib'

# Train UBM and T-matrix on the universal dataset
if os.path.exists(ubm_model_path):
    print("Loading UBM model from file...")
    ubm = joblib.load(ubm_model_path)
else:
    ubm = train_ubm(universal_features)
    joblib.dump(ubm, ubm_model_path)
    print(f"UBM model saved to {ubm_model_path}")

# Load or train T-matrix
if os.path.exists(t_matrix_path):
    print("Loading T-matrix from file...")
    t_matrix = joblib.load(t_matrix_path)
else:
    t_matrix = train_t_matrix(universal_features, supervector_size=6656, n_factors=13)
    joblib.dump(t_matrix, t_matrix_path)
    print(f"T-matrix saved to {t_matrix_path}")
# Out:
# Loading UBM model from file...
# Training T-matrix with 6656 dimensions and 13 factors...
# T-matrix shape: (6656, 13)
# T-matrix trained.
# T-matrix saved to t_matrix.joblib

# %%
individual_files_directory = '/kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one'
# File to save the i-vectors
csv_file = "i_vectors.csv"

# Open the CSV file in write mode
with open(csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    # Write header
    writer.writerow(['Filename'] + [f'i_vector_{i}' for i in range(t_matrix.shape[1])])

    # Process each individual audio file and extract its i-vector
    for filename in os.listdir(individual_files_directory):
        if filename.endswith('.wav'):
            file_path = os.path.join(individual_files_directory, filename)
            print(f"\nProcessing individual file: {file_path}")
            audio_signal, sr = librosa.load(file_path, sr=22050)
            print(f"Loaded audio file with sample rate: {sr}")
            features = extract_features(audio_signal, sr)
            
            # Extract i-vector for the current file using the pre-trained UBM and T-matrix
            i_vector = extract_i_vectors(features, ubm, t_matrix)
            
            # Save the filename and i-vector to the CSV
            writer.writerow([filename] + i_vector.tolist())

        print(f'i-vector for {filename} saved to CSV.')
# Out:
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a101_180_210_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a101_180_210_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a079_120_150_class13.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a079_120_150_class13.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a107_210_240_class1.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a107_210_240_class1.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a059_30_60_class4.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a059_30_60_class4.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a012_60_90_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a012_60_90_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b039_60_90_class8.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b039_60_90_class8.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b033_120_150_class6.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b033_120_150_class6.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a017_120_150_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a017_120_150_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b053_120_150_class10.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b053_120_150_class10.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a109_0_30_class1.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a109_0_30_class1.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a099_120_150_class10.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a099_120_150_class10.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a120_120_150_class10.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a120_120_150_class10.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b116_60_90_class10.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b116_60_90_class10.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b045_0_30_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b045_0_30_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b116_150_180_class10.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b116_150_180_class10.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b005_90_120_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b005_90_120_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b015_150_180_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b015_150_180_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b050_90_120_class1.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b050_90_120_class1.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a121_240_270_class10.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a121_240_270_class10.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b035_0_30_class8.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b035_0_30_class8.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b039_120_150_class8.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b039_120_150_class8.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b092_60_90_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b092_60_90_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b004_0_30_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b004_0_30_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b097_180_210_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b097_180_210_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a020_0_30_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a020_0_30_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b096_120_150_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b096_120_150_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a101_150_180_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a101_150_180_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a026_180_210_class7.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a026_180_210_class7.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b092_120_150_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b092_120_150_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b080_120_150_class13.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b080_120_150_class13.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a098_90_120_class4.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a098_90_120_class4.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a036_90_120_class6.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a036_90_120_class6.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a101_30_60_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a101_30_60_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a097_0_30_class4.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a097_0_30_class4.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b035_30_60_class8.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b035_30_60_class8.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a154_150_180_class13.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a154_150_180_class13.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b093_30_60_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b093_30_60_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a098_150_180_class4.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a098_150_180_class4.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b016_120_150_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b016_120_150_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a019_180_210_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a019_180_210_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a128_161_191_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a128_161_191_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b098_150_180_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b098_150_180_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b094_210_240_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b094_210_240_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a095_120_150_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a095_120_150_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a110_120_150_class5.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a110_120_150_class5.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a019_150_180_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a019_150_180_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b060_60_90_class12.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b060_60_90_class12.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a084_242_272_class9.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a084_242_272_class9.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a154_60_90_class13.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a154_60_90_class13.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a079_270_300_class13.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a079_270_300_class13.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a140_30_60_class0.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a140_30_60_class0.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b012_180_210_class7.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b012_180_210_class7.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a154_30_60_class13.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a154_30_60_class13.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a066_0_30_class4.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a066_0_30_class4.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a060_90_120_class1.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a060_90_120_class1.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a039_120_150_class4.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a039_120_150_class4.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b020_180_210_class7.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b020_180_210_class7.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b038_30_60_class8.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b038_30_60_class8.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b005_150_180_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b005_150_180_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b060_30_60_class12.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b060_30_60_class12.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a098_0_30_class4.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a098_0_30_class4.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b003_60_90_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b003_60_90_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b019_30_60_class7.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b019_30_60_class7.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a003_90_120_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a003_90_120_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a001_150_180_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a001_150_180_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b048_150_180_class8.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b048_150_180_class8.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a122_270_300_class10.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a122_270_300_class10.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a045_90_120_class0.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a045_90_120_class0.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b086_60_90_class5.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b086_60_90_class5.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b099_210_240_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b099_210_240_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a106_30_60_class1.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a106_30_60_class1.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a098_240_270_class4.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a098_240_270_class4.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a157_0_30_class9.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a157_0_30_class9.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b025_150_180_class8.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b025_150_180_class8.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b112_143_173_class0.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b112_143_173_class0.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a129_120_150_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a129_120_150_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a089_150_180_class9.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a089_150_180_class9.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a121_120_150_class10.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a121_120_150_class10.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b095_60_90_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b095_60_90_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a022_0_30_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a022_0_30_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b033_30_60_class6.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b033_30_60_class6.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a121_0_30_class10.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a121_0_30_class10.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a018_0_30_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a018_0_30_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b015_120_150_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b015_120_150_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a155_240_270_class9.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a155_240_270_class9.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b082_120_150_class13.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b082_120_150_class13.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b100_60_90_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b100_60_90_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a031_150_180_class6.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a031_150_180_class6.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a098_210_240_class4.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a098_210_240_class4.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a051_60_90_class5.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a051_60_90_class5.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a156_240_270_class9.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a156_240_270_class9.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b088_0_30_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b088_0_30_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a133_150_180_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a133_150_180_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a155_270_300_class9.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a155_270_300_class9.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b089_0_30_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b089_0_30_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b110_90_120_class0.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b110_90_120_class0.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a075_120_150_class12.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a075_120_150_class12.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b085_60_90_class5.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b085_60_90_class5.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a009_60_90_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a009_60_90_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b075_30_60_class9.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b075_30_60_class9.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b093_150_180_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b093_150_180_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b042_90_120_class8.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b042_90_120_class8.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b029_150_180_class6.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b029_150_180_class6.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a097_120_150_class4.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a097_120_150_class4.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a095_60_90_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a095_60_90_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b016_90_120_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b016_90_120_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b067_0_30_class12.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b067_0_30_class12.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a109_180_210_class1.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a109_180_210_class1.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b030_240_270_class6.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b030_240_270_class6.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b078_60_90_class13.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b078_60_90_class13.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b035_120_150_class8.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b035_120_150_class8.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b011_180_210_class7.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b011_180_210_class7.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b006_60_90_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b006_60_90_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a026_150_180_class7.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a026_150_180_class7.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a104_60_90_class0.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a104_60_90_class0.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a129_180_210_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a129_180_210_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a083_120_150_class1.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a083_120_150_class1.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b036_150_180_class8.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b036_150_180_class8.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b037_60_90_class8.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b037_60_90_class8.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a040_60_90_class4.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a040_60_90_class4.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a155_150_180_class9.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a155_150_180_class9.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b020_0_30_class7.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b020_0_30_class7.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b078_180_210_class13.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b078_180_210_class13.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a156_0_30_class9.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a156_0_30_class9.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a106_270_300_class1.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a106_270_300_class1.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b072_240_270_class9.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b072_240_270_class9.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b055_137_167_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b055_137_167_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a089_240_270_class9.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a089_240_270_class9.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b087_60_90_class5.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b087_60_90_class5.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a023_120_150_class7.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a023_120_150_class7.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b096_270_300_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b096_270_300_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b087_30_60_class5.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b087_30_60_class5.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a116_138_168_class5.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a116_138_168_class5.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a096_30_60_class4.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a096_30_60_class4.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b109_0_30_class0.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b109_0_30_class0.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a098_30_60_class4.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a098_30_60_class4.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a058_150_180_class4.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a058_150_180_class4.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a053_60_90_class1.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a053_60_90_class1.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b096_150_180_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b096_150_180_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b030_120_150_class6.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b030_120_150_class6.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b038_90_120_class8.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b038_90_120_class8.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b006_0_30_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b006_0_30_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b007_180_210_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b007_180_210_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b045_30_60_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b045_30_60_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b008_120_150_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b008_120_150_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b096_180_210_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b096_180_210_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a071_60_90_class0.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a071_60_90_class0.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a112_30_60_class0.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a112_30_60_class0.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b059_30_60_class12.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b059_30_60_class12.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a140_210_240_class0.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a140_210_240_class0.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a059_90_120_class4.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a059_90_120_class4.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a104_120_150_class0.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a104_120_150_class0.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a121_180_210_class10.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a121_180_210_class10.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a034_90_120_class6.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a034_90_120_class6.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a156_120_150_class9.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a156_120_150_class9.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b096_90_120_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b096_90_120_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b072_30_60_class9.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b072_30_60_class9.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a006_30_60_class7.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a006_30_60_class7.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a126_120_150_class1.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a126_120_150_class1.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b072_180_210_class9.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b072_180_210_class9.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b087_90_120_class5.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b087_90_120_class5.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a001_30_60_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a001_30_60_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a145_30_60_class12.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a145_30_60_class12.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a062_0_30_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a062_0_30_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a023_0_30_class7.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a023_0_30_class7.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b087_120_150_class5.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b087_120_150_class5.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a082_30_60_class1.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a082_30_60_class1.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b078_150_180_class13.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b078_150_180_class13.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a021_0_30_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a021_0_30_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b004_60_90_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b004_60_90_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a023_30_60_class7.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a023_30_60_class7.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a019_60_90_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a019_60_90_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b009_120_150_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b009_120_150_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b109_120_150_class0.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b109_120_150_class0.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a045_60_90_class0.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a045_60_90_class0.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b041_30_60_class8.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b041_30_60_class8.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b092_30_60_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b092_30_60_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b103_30_60_class5.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b103_30_60_class5.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a145_60_90_class12.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a145_60_90_class12.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b020_30_60_class7.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b020_30_60_class7.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a099_0_30_class10.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a099_0_30_class10.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a104_0_30_class0.wav
# ...
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a053_120_150_class1.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a113_215_245_class5.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a113_215_245_class5.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b034_120_150_class8.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b034_120_150_class8.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b100_120_150_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b100_120_150_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a017_180_210_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a017_180_210_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b112_30_60_class0.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b112_30_60_class0.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b098_0_30_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b098_0_30_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a109_120_150_class1.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a109_120_150_class1.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a036_150_180_class6.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a036_150_180_class6.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a096_150_180_class4.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a096_150_180_class4.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a089_60_90_class9.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a089_60_90_class9.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b094_30_60_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b094_30_60_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b041_180_210_class8.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b041_180_210_class8.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a012_30_60_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a012_30_60_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a074_150_180_class12.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a074_150_180_class12.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b021_120_150_class7.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b021_120_150_class7.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a156_90_120_class9.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a156_90_120_class9.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a020_162_192_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a020_162_192_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a014_120_150_class7.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a014_120_150_class7.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a113_245_275_class5.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a113_245_275_class5.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a027_0_30_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a027_0_30_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a012_180_210_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a012_180_210_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a126_60_90_class1.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a126_60_90_class1.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b107_60_90_class0.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b107_60_90_class0.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b110_210_240_class0.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b110_210_240_class0.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b065_54_84_class12.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b065_54_84_class12.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b086_30_60_class5.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b086_30_60_class5.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a121_60_90_class10.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a121_60_90_class10.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a018_90_120_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a018_90_120_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b093_90_120_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b093_90_120_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a019_0_30_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a019_0_30_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a140_0_30_class0.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a140_0_30_class0.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a153_270_300_class13.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a153_270_300_class13.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b039_30_60_class8.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b039_30_60_class8.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a154_180_210_class13.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a154_180_210_class13.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a074_210_240_class12.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a074_210_240_class12.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b037_0_30_class8.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b037_0_30_class8.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a120_240_270_class10.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a120_240_270_class10.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b038_210_240_class8.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b038_210_240_class8.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b072_150_180_class9.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b072_150_180_class9.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b109_60_90_class0.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b109_60_90_class0.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a058_120_150_class4.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a058_120_150_class4.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b078_90_120_class13.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b078_90_120_class13.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a084_182_212_class9.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a084_182_212_class9.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a003_180_210_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a003_180_210_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b016_0_30_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b016_0_30_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a133_120_150_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a133_120_150_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b021_150_180_class7.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b021_150_180_class7.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a083_60_90_class1.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a083_60_90_class1.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a034_0_30_class6.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a034_0_30_class6.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a052_90_120_class1.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a052_90_120_class1.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b099_180_210_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b099_180_210_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b088_180_210_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b088_180_210_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a131_60_90_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a131_60_90_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a137_60_90_class2.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a137_60_90_class2.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a027_30_60_class14.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a027_30_60_class14.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a140_60_90_class0.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a140_60_90_class0.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b005_0_30_class11.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b005_0_30_class11.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a005_0_30_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a005_0_30_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/b091_122_152_class3.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for b091_122_152_class3.wav saved to CSV.
#
# Processing individual file: /kaggle/input/tut-2016/TUT_2016/TUT_Acoustic_scenes_development_all_in_one/a109_210_240_class1.wav
# Loaded audio file with sample rate: 22050
# Extracting i-vector...
# i-vector shape: (13,)
# i-vector for a109_210_240_class1.wav saved to CSV.
